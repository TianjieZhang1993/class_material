# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler

# %%
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), np.array([1 for x in range(n_samples)])

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# %%
data=aniso
data=varied
data=noisy_moons
data=noisy_circles
data=blobs
color=['red','blue','orange','black', 'purple','pink']
X,y=data
plt.scatter(X[:,0], X[:,1],  c=np.array([color[x] for x in y] ))
plt.show()

# %%
from sklearn.cluster import KMeans
clustering = KMeans(n_clusters=3, random_state=0).fit(X)
pred=clustering.predict(X)
plt.scatter(X[:,0], X[:,1],  c=np.array([color[x] for x in pred] ))
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(X)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
sse
# Out:
# {1: 1505.5420970664013,
#  2: 606.4428647203639,
#  3: 405.53290591551945,
#  4: 264.90539662108904,
#  5: 198.99174288321828,
#  6: 137.18921176125605,
#  7: 109.14551841471152,
#  8: 81.06690691821532,
#  9: 66.8707031582556}

# %%
from sklearn.cluster import DBSCAN
pred = DBSCAN(eps=0.09, min_samples=3).fit_predict(X)

plt.scatter(X[:,0], X[:,1],  c=np.array([color[x%6] if x>=0 else 'green' for x in pred ] ))
plt.show()

# %%
pred
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
from sklearn import cluster, datasets, mixture
clustering = mixture.GaussianMixture(n_components=3, covariance_type='full').fit(X)
pred=clustering.predict(X)
plt.scatter(X[:,0], X[:,1],  c=np.array([color[x] for x in pred] ))
plt.show()

# %%
clustering.sample(3)
# Out:
# (array([[ -4.19427824, -11.51709185],
#         [  7.2553007 ,   2.18502262],
#         [  6.3769593 ,  -0.46927706]]), array([1, 2, 2]))
